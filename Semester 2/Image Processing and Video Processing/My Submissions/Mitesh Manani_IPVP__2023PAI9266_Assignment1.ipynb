# %%
import imageio.v3 as iio
import  matplotlib.pyplot as plt
import numpy as np

# %%
image_url = r"C:\Users\mites\OneDrive\Desktop\eight.tif"
zero = iio.imread(image_url)
one = iio.imread(image_url)
two = iio.imread(image_url)
three = iio.imread(image_url)
four = iio.imread(image_url)
five = iio.imread(image_url)
six = iio.imread(image_url)
seven = iio.imread(image_url)
eight = iio.imread(image_url)
nine = iio.imread(image_url)

zero = np.ones(zero.shape)
zero[1][1] = 0.
zero[2][1] = 0.
zero[3][1] = 0.
one[2][1] = 1. 
two[1][0] = 1. 
two[3][2] = 1.
three[1][0] = 1. 
three[3][0] = 1. 
four[0][1] = 1. 
four[3][0] = 1. 
four[4][0] = 1. 
four[4][1] = 1. 
five[1][2] = 1. 
five[3][0] = 1. 
six[1][2] = 1. 
seven[1][0] = 1. 
seven[2][0] = 1. 
seven[2][1] = 1.
seven[3][0] = 1.
seven[3][1] = 1.
seven[4][0] = 1.
seven[4][1] = 1.
nine[3][0] = 1.

# %%
fig, axes = plt.subplots(4, 3, figsize=(10, 10))
 

images_list = [zero,one,two,three,four,five,six,seven,eight,nine]

for i , img in enumerate(images_list):
    ax = axes[i // 3, i % 3] 
    
    ax.imshow(img)  
    ax.set_title(f"Image {i}")
     

 
plt.tight_layout()
plt.show()
